# %% [markdown]
# <a href="https://colab.research.google.com/github/AnirudhJM24/license_plate_yolov3/blob/main/training_yolov3_license_plate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15395, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 15395 (delta 2), reused 5 (delta 1), pack-reused 15387
# Receiving objects: 100% (15395/15395), 14.04 MiB | 18.53 MiB/s, done.
# Resolving deltas: 100% (10348/10348), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
! make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
import os

# %%
IMG_DIR = r'/content/drive/MyDrive/licenseplate/train'
print(os.listdir(IMG_DIR))
# Out:
# ['09453a7c716a9ef3_jpg.rf.5776237b99f425a57da152b3a1adecc3.jpg', '08481c03daf6f35d_jpg.rf.227b7230a71039b5f5a5b6803aa1e22c.txt', '08481c03daf6f35d_jpg.rf.227b7230a71039b5f5a5b6803aa1e22c.jpg', '081f5a6bc61b9c48_jpg.rf.49240c093b301a8a596f1212de40d56e.jpg', '09453a7c716a9ef3_jpg.rf.5776237b99f425a57da152b3a1adecc3.txt', '0c756c9366a8cb10_jpg.rf.5448d5081af4eddc034b35111e17a035.jpg', '091c033b2a7df15b_jpg.rf.40e8c5f73ca1cdb7cd643d110312847b.jpg', '091c033b2a7df15b_jpg.rf.40e8c5f73ca1cdb7cd643d110312847b.txt', '0c756c9366a8cb10_jpg.rf.5448d5081af4eddc034b35111e17a035.txt', '081f5a6bc61b9c48_jpg.rf.49240c093b301a8a596f1212de40d56e.txt', '0787b0fa95f545a5_jpg.rf.5918f5ea12fee9653f005937787e7cd2.txt', '06b024413ad385a7_jpg.rf.31adef3948b22c2f24716638c98e543b.txt', '0727983dd5f9e4e6_jpg.rf.8c94837c18980170b58739110124bac8.txt', '0801961485534636_jpg.rf.6a30289a294b84db92e68e901cefb15e.txt', '0787b0fa95f545a5_jpg.rf.5918f5ea12fee9653f005937787e7cd2.jpg', '0673b967f8c68eec_jpg.rf.4faffea417c0
# ...

# %%
all_files_list = os.listdir(IMG_DIR)

fcount = len(all_files_list)
img_list = []
i = 0

while i < fcount:
    img_list.append(all_files_list[i])
    i +=1
    
    
print(len(img_list))
# Out:
# 490

# %%
print(img_list)
# Out:
# ['09453a7c716a9ef3_jpg.rf.5776237b99f425a57da152b3a1adecc3.jpg', '08481c03daf6f35d_jpg.rf.227b7230a71039b5f5a5b6803aa1e22c.txt', '08481c03daf6f35d_jpg.rf.227b7230a71039b5f5a5b6803aa1e22c.jpg', '081f5a6bc61b9c48_jpg.rf.49240c093b301a8a596f1212de40d56e.jpg', '09453a7c716a9ef3_jpg.rf.5776237b99f425a57da152b3a1adecc3.txt', '0c756c9366a8cb10_jpg.rf.5448d5081af4eddc034b35111e17a035.jpg', '091c033b2a7df15b_jpg.rf.40e8c5f73ca1cdb7cd643d110312847b.jpg', '091c033b2a7df15b_jpg.rf.40e8c5f73ca1cdb7cd643d110312847b.txt', '0c756c9366a8cb10_jpg.rf.5448d5081af4eddc034b35111e17a035.txt', '081f5a6bc61b9c48_jpg.rf.49240c093b301a8a596f1212de40d56e.txt', '0787b0fa95f545a5_jpg.rf.5918f5ea12fee9653f005937787e7cd2.txt', '06b024413ad385a7_jpg.rf.31adef3948b22c2f24716638c98e543b.txt', '0727983dd5f9e4e6_jpg.rf.8c94837c18980170b58739110124bac8.txt', '0801961485534636_jpg.rf.6a30289a294b84db92e68e901cefb15e.txt', '0787b0fa95f545a5_jpg.rf.5918f5ea12fee9653f005937787e7cd2.jpg', '0673b967f8c68eec_jpg.rf.4faffea417c0
# ...

# %%
# !chmod +x '/content/drive/MyDrive/SCIIproject/yolo'

# %%
COLAB_DIR = '/content/drive/MyDrive/licenseplate/train'

with open("train.txt",'w') as file_obj:
    for fname in img_list:
        file_obj.write(COLAB_DIR + '/' + fname)
        if fname.endswith('.jpg'):

          print(COLAB_DIR + '/'  + fname)

        
file_obj.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c10fa913f0c5> in <module>()
#       2
#       3 with open("train.txt",'w') as file_obj:
# ----> 4     for fname in img_list:
#       5         file_obj.write(COLAB_DIR + '/' + fname)
#       6         if fname.endswith('.jpg'):
#
# NameError: name 'img_list' is not defined

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab import files
# %matplotlib inline

# define helper functions
def imShow(path):

  image = cv2.imread(path)

  if image is None:
        print("{} was not found".format(path))
        return
    
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
! pwd
# Out:
# /content/darknet

# %%
# !./darknet detector
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# usage: ./darknet detector [train/test/valid/demo/map] [data] [cfg] [weights (optional)]

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2022-01-09 07:41:12--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  23.3MB/s    in 11s
#
# 2022-01-09 07:41:23 (21.6 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !chmod +x '/content/drive/MyDrive/SCIIproject/annotated'

# %%
# !./darknet detector train
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# usage: ./darknet detector [train/test/valid/demo/map] [data] [cfg] [weights (optional)]

# %%
# !./darknet detector train /content/drive/MyDrive/licenseplate/yolo/data.data /content/drive/MyDrive/licenseplate/yolo/yolov3_custom.cfg /content/drive/MyDrive/licenseplate/backup/yolov3_custom_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 100677, rewritten_bbox = 0.087408 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.801141), count: 5, class_loss = 0.273476, iou_loss = 0.142787, total_loss = 0.416262
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.803703), count: 4, class_loss = 0.308056, iou_loss = 0.158421, total_loss = 0.466476
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.716948), count: 2, class_loss = 0.238095, iou_loss = 0.173468, total_loss = 0.411563
#  total_bbox = 100688, rewritten_bbox = 0.087399 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.807117), count: 6, class_loss = 0.838014, iou_loss = 0.172234, total_loss = 1.010248
# ...

# %%
# !./darknet detector test /content/drive/MyDrive/licenseplate/yolo/data.data /content/drive/MyDrive/licenseplate/yolo/yolov3_custom.cfg /content/drive/MyDrive/licenseplate/backup/yolov3_custom_final.weights /content/86c92b0402fec141_jpg.rf.a35170b73727f3b88b332b02251071d2.jpg
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
